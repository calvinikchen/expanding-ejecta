# %%
import numpy as np
import pandas as pd
import scipy.special as sp
import matplotlib.pyplot as plt
import healpy as hp
import scipy.constants as const
import scipy.optimize as op
import scipy.integrate as integrate
import matplotlib as mpl
from P_cygni import P_cygni

# %%
plt.rcdefaults()
fontsize = 14
from matplotlib import font_manager
from matplotlib import rcParams
from matplotlib import rc

cmfont = font_manager.FontProperties(fname=mpl.get_data_path() + '/fonts/ttf/cmr10.ttf')
plt.rcParams['font.serif']=cmfont.get_name()
params = {"ytick.color" : "black",
          "xtick.color" : "black",
          "axes.labelcolor" : "black",
          "axes.edgecolor" : "black",
          "font.size" : fontsize,
          "text.usetex" : True,
          "mathtext.fontset" : "cm",
          "font.family" : "serif",
          "font.serif" : [cmfont.get_name()],
          "text.latex.preamble" : r"\usepackage{amsmath}"}
plt.rcParams['axes.unicode_minus']=False
plt.rcParams.update(params)

# %%
def b_nu(nu, temp):
    return 2*const.h*nu**3/const.c**2/(np.exp(const.h*nu/const.k/temp)-1)

def b_lam(lam, temp):
    return 2*const.h*const.c**2/lam**5/(np.exp(const.h*const.c/const.k/temp/lam)-1)


def flux_nu(nu, temp = 6000, r_sn = 1e13, d_sn = 1e6*const.parsec):
    return (r_sn/d_sn)**2*b_nu(nu, temp)*1e26

def flux_lam(nu, temp = 6000, r_sn = 1e13, d_sn = 1e6*const.parsec):
    return (r_sn/d_sn)**2*b_lam(nu, temp)

# %%
lam_ar = np.arange(1000,100,-1)*1e-9
nu_ar = const.c/lam_ar

flux_nu_ar = b_nu(nu_ar, 6000)
flux_lam_ar = b_lam(lam_ar, 6000)

# %%
lam0 = 656.46e-9
nu0 = const.c/lam0

th_max = 8e6*10*const.day/const.parsec/1e7

lam_obs = np.arange(1/.9, 1/1.1, -.0001)*lam0
nu_obs = const.c/lam_obs
th_ar = np.linspace(0, 2*th_max, 1001)

# variable to calculate the spatially-integrated spectrum
th_mid = (th_ar[1:] + th_ar[:-1])/2
d_th = th_ar[1] - th_ar[0]

# %%
nu_ar
# Out:
# array([2.99792458e+14, 3.00092551e+14, 3.00393244e+14, 3.00694542e+14,
#        3.00996444e+14, 3.01298953e+14, 3.01602070e+14, 3.01905799e+14,
#        3.02210139e+14, 3.02515094e+14, 3.02820665e+14, 3.03126853e+14,
#        3.03433662e+14, 3.03741092e+14, 3.04049146e+14, 3.04357825e+14,
#        3.04667132e+14, 3.04977068e+14, 3.05287635e+14, 3.05598836e+14,
#        3.05910671e+14, 3.06223144e+14, 3.06536256e+14, 3.06850008e+14,
#        3.07164404e+14, 3.07479444e+14, 3.07795131e+14, 3.08111468e+14,
#        3.08428455e+14, 3.08746095e+14, 3.09064390e+14, 3.09383342e+14,
#        3.09702952e+14, 3.10023224e+14, 3.10344159e+14, 3.10665760e+14,
#        3.10988027e+14, 3.11310964e+14, 3.11634572e+14, 3.11958853e+14,
#        3.12283810e+14, 3.12609445e+14, 3.12935760e+14, 3.13262757e+14,
#        3.13590437e+14, 3.13918804e+14, 3.14247860e+14, 3.14577605e+14,
#        3.14908044e+14, 3.15239178e+14, 3.15571008e+14, 3.15903538e+14,
# ...

# %%
spec = P_cygni(nu_ar, th_obs = th_ar, nu0 = nu0, ds = const.parsec*1e7)


spec.opt_depth(tau0 = 20, n = 5)

# calculate the line profile
spec.absorption()
spec.emission()
# Out:
# /Users/calvinchen/Documents/EPM/P_cygni.py:120: RuntimeWarning: divide by zero encountered in true_divide
#   w = 1/2*(1-np.sqrt(np.abs(1-(self.v0/self.vel)**2)))*(self.vel!=0)
# /Users/calvinchen/Documents/EPM/P_cygni.py:120: RuntimeWarning: invalid value encountered in multiply
#   w = 1/2*(1-np.sqrt(np.abs(1-(self.v0/self.vel)**2)))*(self.vel!=0)
# /Users/calvinchen/Documents/EPM/P_cygni.py:145: RuntimeWarning: divide by zero encountered in true_divide
#   tau = np.abs(tau0*(self.v0/self.vel)**(n)*(self.vel!=0))
# /Users/calvinchen/Documents/EPM/P_cygni.py:145: RuntimeWarning: invalid value encountered in true_divide
#   tau = np.abs(tau0*(self.v0/self.vel)**(n)*(self.vel!=0))
# /Users/calvinchen/Documents/EPM/P_cygni.py:145: RuntimeWarning: invalid value encountered in power
#   tau = np.abs(tau0*(self.v0/self.vel)**(n)*(self.vel!=0))

# %%
p_cyg_abs = np.sum(spec.pcyg_abs*spec.th_obs, axis = 0)*2/spec.th_max**2*d_th
p_cyg_em = np.sum(spec.pcyg_em*spec.th_obs, axis = 0)*2/spec.th_max**2*d_th

line = p_cyg_abs + p_cyg_em

# %%
plt.imshow(np.flip(spec.pcyg_em + spec.pcyg_abs), 
           aspect = 'auto', vmin = 0, vmax = 1, cmap = 'RdBu_r')
# Out:
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/2194886256.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.imshow(np.flip(spec.pcyg_em + spec.pcyg_abs),

# %%
plt.plot(lam_ar, p_cyg_abs + p_cyg_em)
# Out:
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/3445621447.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(lam_ar, p_cyg_abs + p_cyg_em)

# %%
plt.plot(nu_ar/1e9, flux_nu_ar*line)
plt.xlabel('frequency [GHz]')
plt.ylabel('$\\text{W}\cdot \\text{m}^{-2}\cdot \\text{Hz}^{-1}\cdot \\text{sr}^{-1}$')
#plt.yscale('log')
#plt.xscale('log')
plt.xlim(0.3e6,.7e6)
plt.axvline(nu0/1e9, color = 'k', linestyle = '--')
# Out:
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/2350744107.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(nu_ar/1e9, flux_nu_ar*line)

# %%
plt.plot(lam_ar*1e10, flux_lam_ar/1e10*line)
plt.xlabel('wavelength [$\\text{\AA}$]')
plt.ylabel('$\\text{W}\cdot \\text{m}^{-2}\cdot \\text{\AA}^{-1}\cdot \\text{sr}^{-1}$')
plt.xlim(5e3,8e3)
plt.axvline(lam0*1e10, color = 'k', linestyle = '--')
# Out:
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/2272567900.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(lam_ar*1e10, flux_lam_ar/1e10*line)

# %%
class P_cygni(object):
    
    def __init__(self, nu_obs, th_obs, v0 = 8e6, nu0 = 1, ds = const.parsec*1e6, t = 10*const.day):
        self.nu_obs = np.expand_dims(nu_obs, axis = 0)
        self.th_obs = np.expand_dims(th_ar, axis = 1)
        self.v0 = v0
        self.nu0 = nu0
        self.ds = ds
        self.t = t
        self.th_max = v0*t/ds
        self.vel = self.get_v()
        self.geo_w = self.get_geo_W()
        #self.opt_depth = self.get_tau()
        
    def get_v(self):
        vel = np.sqrt((self.ds*self.th_obs/self.t)**2 + 
                      (1- self.nu0/self.nu_obs)**2*const.c**2)*np.sign(1- self.nu0/self.nu_obs)
        cond = (vel > self.v0) + (self.th_obs > self.th_max)
        
        return vel*cond


    def opt_depth(self, tau0 = 2, n = 5):
        
        tau = np.abs(tau0*(self.v0/self.vel)**(n)*(self.vel!=0))
        self.tau = np.nan_to_num(tau, nan = 0)
    
    def get_geo_W(self):
        w = 1/2*(1-np.sqrt(1-(self.v0/self.vel)**2))*(self.vel!=0)
        return np.nan_to_num(w, nan = 0)
    
    
    def get_abs(self):
        return np.exp(-self.tau)*(self.th_obs <= self.th_max)
        #w = 1/2*(1-np.sqrt(1-(self.v0/self.vel)**2))*(self.vel!=0)
        #return np.nan_to_num(w, nan = 0)

    def get_em(self):
        return (1 - np.exp(-self.tau))*self.geo_w

# %%
th_max = 8e6*10*const.day/const.parsec/1e6

lam_obs = np.arange(1/.9, 1/1.1, -.0001)
nu_obs = 1/lam_obs
th_ar = np.linspace(0, 2*th_max, 1001)
th_mid = (th_ar[1:] + th_ar[:-1])/2
d_th = th_ar[1] - th_ar[0]


spec = P_cygni(nu_obs, th_ar)
spec.opt_depth(tau0 = 2, n = 5)
# Out:
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1859617785.py:29: RuntimeWarning: divide by zero encountered in true_divide
#   w = 1/2*(1-np.sqrt(1-(self.v0/self.vel)**2))*(self.vel!=0)
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1859617785.py:29: RuntimeWarning: invalid value encountered in sqrt
#   w = 1/2*(1-np.sqrt(1-(self.v0/self.vel)**2))*(self.vel!=0)
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1859617785.py:25: RuntimeWarning: divide by zero encountered in true_divide
#   tau = np.abs(tau0*(self.v0/self.vel)**(n)*(self.vel!=0))
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1859617785.py:25: RuntimeWarning: invalid value encountered in multiply
#   tau = np.abs(tau0*(self.v0/self.vel)**(n)*(self.vel!=0))

# %%
p_cyg_abs = np.sum(spec.get_abs()*spec.th_obs, axis = 0)*2/spec.th_max**2*d_th
p_cyg_em = np.sum(spec.get_em()*spec.th_obs, axis = 0)*2/spec.th_max**2*d_th

# %%
fig = plt.figure(figsize = (10,4))
plt.subplot(121)
plt.imshow(np.flip(spec.get_abs()),extent=((1/nu_obs[-1]-1)*const.c/8e6, (1/nu_obs[0]-1)*const.c/8e6, 0, 2), 
           aspect = 'auto', vmin = 0, vmax = 1, cmap = 'gray')
plt.axvline(-1, color = 'r', linestyle = '--')
plt.colorbar()
plt.xlabel('$v~[v_\\text{ph}]$')
plt.ylabel('$\\theta~[\\theta_\\text{ph}]$')
plt.title('$\\theta$-dependent absorption')


plt.subplot(122)
plt.plot((1/nu_obs-1)*const.c/8e6, p_cyg_abs, 'k-', lw = 2)
plt.axvline(-1, color = 'r', linestyle = '--')
plt.xlabel('$v~[v_\\text{ph}]$')
plt.ylabel('relative flux')
plt.title('integrated absorption')
#plt.savefig('P_cygni_abs.png', bbox_inches = 'tight')
# Out:
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1078436887.py:2: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.subplot(121)
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1078436887.py:6: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar()
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1078436887.py:12: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.subplot(122)
# Text(0.5, 1.0, 'integrated absorption')

# %%
fig = plt.figure(figsize = (10,4))
plt.subplot(121)
plt.imshow(np.flip(spec.get_em()),extent=((1/nu_obs[-1]-1)*const.c/8e6, (1/nu_obs[0]-1)*const.c/8e6, 0, 2), 
           aspect = 'auto', vmin = 0, vmax = 1, cmap = 'gray')
plt.axvline(-1, color = 'r', linestyle = '--')
plt.colorbar()
plt.xlabel('$v~[v_\\text{ph}]$')
plt.ylabel('$\\theta~[\\theta_\\text{ph}]$')
plt.title('$\\theta$-dependent absorption')


plt.subplot(122)
plt.plot((1/nu_obs-1)*const.c/8e6, p_cyg_em, 'k-', lw = 2)
plt.axvline(-1, color = 'r', linestyle = '--')
plt.xlabel('$v~[v_\\text{ph}]$')
plt.ylabel('relative flux')
plt.title('integrated absorption')
#plt.savefig('P_cygni_abs.png', bbox_inches = 'tight')
# Out:
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1729532228.py:2: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.subplot(121)
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1729532228.py:6: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar()
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/1729532228.py:12: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.subplot(122)
# Text(0.5, 1.0, 'integrated absorption')

# %%
fig = plt.figure(figsize = (9,4),layout="constrained")
plt.subplot(121)
plt.imshow(np.log10(np.flip(spec.get_em() + spec.get_abs())),extent=((1/nu_obs[-1]-1)*const.c/8e6, 
                                                           (1/nu_obs[0]-1)*const.c/8e6, 0, 2), 
           aspect = 'auto', vmin = -2, vmax = 0, cmap = 'inferno')
plt.axvline(-.75, color = 'b', linestyle = '--')
plt.axvline(.75, color = 'r', linestyle = '--')
plt.colorbar(label = r'$\log_{10}{I_\lambda/I_\text{ph}}$', ticks=[-2,-1.5, -1,-0.5, 0])
plt.xlabel('$v~[v_\\text{ph}]$')
plt.ylabel(r'$\theta~[\Theta_\text{ph}]$')
plt.title('$\\theta$-dependent intensity')
plt.xlim(-2, 2)


plt.subplot(122)
plt.plot((1/nu_obs-1)*const.c/8e6, p_cyg_em + p_cyg_abs, 'k-', lw = 2)
plt.axvline(-.75, color = 'b', linestyle = '--')
plt.axvline(.75, color = 'r', linestyle = '--')
plt.xlabel('$v~[v_\\text{ph}]$')
plt.ylabel('relative flux')
plt.ylim(0.5,1.3)
#plt.xlim(-20/8, 20/8)
plt.xlim(-2, 2)
plt.title('integrated intensity')
#plt.constraint_layout()
plt.savefig('P_cygni_full.pdf', bbox_inches = 'tight')
# Out:
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/3751923976.py:2: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.subplot(121)
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/3751923976.py:8: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar(label = r'$\log_{10}{I_\lambda/I_\text{ph}}$', ticks=[-2,-1.5, -1,-0.5, 0])
# /var/folders/fv/3x8pf_d96p9dfcdmdd8v28kh0000gn/T/ipykernel_1472/3751923976.py:15: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.subplot(122)

# %%
nu_em = np.arange(.9, 1.1, .001)
th_em = np.linspace(th_max, 2*th_max, 101)

# %%
tau_em = opt_depth(solve_v(np.expand_dims(nu_em, axis = 0), 
                           np.expand_dims(th_em, axis = 1)))

tau_em = np.nan_to_num(tau_em, nan = 0)

# %%
plt.plot((1/nu_em-1)*const.c/8e6, opt_depth(solve_v(nu_em, th_max*2)))

# %%
th_max/const.degree*3600*1e6
# Out:
# 46.2038661891195
